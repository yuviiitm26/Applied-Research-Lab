# %% [markdown]
# <a href="https://colab.research.google.com/github/yuviiitm26/Applied-Research-Lab/blob/main/GPT%20Tokenizer/Tokenization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Tokenization :(
# Tokenization is at the heart of much weirdness of LLMs. Do not brush it off.
#
# * Why can't LLM spell words? Tokenization
# * Why can't LLM do super simple string processing tasks like revering a string? Tokenization
# * why is the LLm worse at non-english languages (eg. japanese)? Tokenization.
# * why is LLM bad at simple arithmetic? Tiokenization.
# * why did gpt-2 have more
# then necessary trouble coding in Python? Tokenization
# * why did my llm abruptly halt when it sees the string "<|endoftext|>"? tokenization.
# * why is this weird warning i get about a "trailing whitespace"? Tokenization.
# * why the llm break if i ask it about "solidGOldMagikarp"? Tokenization.
# * why should I prefer to use YAML over json with LLms? Tokenization.
# * why is LLM not actually end to end language modeling? Tokenization.
# * what is the real root of suffering ? Tokenization.

# %%
"नमस्ते (HELLO IN SANSKRIT!)"

# %%
[ord(x) for x in "नमस्ते (HELLO IN SANSKRIT!)"]
# Out:
# [2344,
#  2350,
#  2360,
#  2381,
#  2340,
#  2375,
#  32,
#  40,
#  72,
#  69,
#  76,
#  76,
#  79,
#  32,
#  73,
#  78,
#  32,
#  83,
#  65,
#  78,
#  83,
#  75,
#  82,
#  73,
#  84,
#  33,
#  41]

# %%
list("नमस्ते (HELLO IN SANSKRIT!)".encode("utf-8"))
# Out:
# [224,
#  164,
#  168,
#  224,
#  164,
#  174,
#  224,
#  164,
#  184,
#  224,
#  165,
#  141,
#  224,
#  164,
#  164,
#  224,
#  165,
#  135,
#  32,
#  40,
#  72,
#  69,
#  76,
#  76,
#  79,
#  32,
#  73,
#  78,
#  32,
#  83,
#  65,
#  78,
#  83,
#  75,
#  82,
#  73,
#  84,
#  33,
#  41]
